# %% [markdown]
# # 1. Data Collection

# %% [markdown]
# ### Import Required Libraries
# Import the necessary libraries, including pandas and json.

# %%
# Import the necessary libraries, including pandas and json
import pandas as pd
import json
import os

# %% [markdown]
# ### Please change year to the year you want

# %%
# Change year to the year you want
year = 2018

# %%
# Define the path to the folder containing files
folder_path = f'Project/{year}'

# Loop through all files in the folder
for filename in os.listdir(folder_path):
    if filename.startswith(str(year)) and not filename.endswith('.json'):
        old_file_path = os.path.join(folder_path, filename)
        new_file_path = os.path.join(folder_path, filename + '.json')
        
        # Rename the file
        os.rename(old_file_path, new_file_path)
        # print(f"Renamed {old_file_path} to {new_file_path}")

print("Renaming completed.")
# Out:
# Renaming completed.

# %% [markdown]
# ### Load JSON File
# Load the JSON file from the specified path.

# %%
# Path to the folder containing JSON files
folder_path = f'Project/{year}'

# Initialize a list to store the rows of the DataFrame
data_rows = []

# Columns to extract
columns_to_keep = [
    'coredata.srctype',
    'coredata.eid',
    'coredata.dc:description',
    'coredata.pubmed-id',
    'coredata.prism:coverDate',
    'coredata.prism:aggregationType',
    'coredata.prism:url',
    'coredata.source-id',
    'coredata.pii',
    'coredata.citedby-count',
    'coredata.prism:volume',
    'coredata.subtype',
    'coredata.dc:title',
    'coredata.openaccess',
    'coredata.prism:issn',
    'coredata.publishercopyright',
    'coredata.article-number',
    'coredata.subtypeDescription',
    'coredata.prism:publicationName',
    'coredata.prism:doi',
    'coredata.dc:identifier',
    'coredata.dc:publisher',
    'item.bibrecord.head.citation-info.citation-language.@language',
]

# Helper function to safely extract a value from a dictionary
def safe_get(d, keys, default=None):
    try:
        for key in keys:
            d = d.get(key, {})
        return d if d else default
    except AttributeError:
        return default

# Iterate through each file in the folder
for file_name in os.listdir(folder_path):
    if file_name.startswith(str(year)) and file_name.endswith(".json"):
        file_path = os.path.join(folder_path, file_name)
        with open(file_path, 'r', encoding='utf-8') as file:
            try:
                data = json.load(file)

                # Extract countries from author-group
                author_groups = safe_get(data, ['abstracts-retrieval-response', 'item', 'bibrecord', 'head', 'author-group'], [])
                countries = [
                    safe_get(author, ['affiliation', 'country'], 'Unknown')
                    for author in author_groups
                ]
                countries_string = ','.join(countries)

                # Extract keywords
                auth_keywords = safe_get(data, ['abstracts-retrieval-response', 'authkeywords', 'author-keyword'], [])
                keywords = [keyword.get('$', '') for keyword in auth_keywords if isinstance(keyword, dict)]
                keywords_string = ','.join(keywords) if keywords else 'null'

                # Normalize JSON data and filter columns
                row_data = pd.json_normalize(data.get('abstracts-retrieval-response', {}))
                row = {col: row_data[col].iloc[0] if col in row_data else pd.NA for col in columns_to_keep}

                # Add processed fields
                row['item.bibrecord.head.author-group.affiliation.country'] = countries_string
                row['authkeywords.author-keyword'] = keywords_string

                # Append the row to data_rows
                data_rows.append(row)

            except Exception as e:
                print(f"Error processing file {file_name}: {e}")

# Convert the list of rows into a DataFrame
df = pd.DataFrame(data_rows)

# Save the DataFrame to a CSV file
output_path = f'output_{year}.csv'
df.to_csv(output_path, index=False, encoding='utf-8')

# %%
df.describe()
# Out:
#        coredata.srctype        coredata.eid  \
# count              2890                2890
# unique                5                2890
# top                   j  2-s2.0-85170238281
# freq               2674                   1
#
#                                   coredata.dc:description coredata.pubmed-id  \
# count                                                2798               1050
# unique                                               2798               1050
# top     Pyrocatechol violet/copper ion-graphene oxide/...           37633552
# freq                                                    1                  1
#
#        coredata.prism:coverDate coredata.prism:aggregationType  \
# count                      2890                           2890
# unique                      174                              5
# top                  2023-01-01                        Journal
# freq                       1027                           2674
#
#                                        coredata.prism:url coredata.source-id  \
# count                                                2890               2890
# unique                                               2890               1502
# top     https://api.elsevier.com/content/abstract/scop...        21100200805
# freq                                                    1                 96
#
#              coredata.pii coredata.citedby-count  ...  \
# count                 757                   2888  ...
# unique                757                     21  ...
# top     S0141813023032129                      0  ...
# freq                    1                   2019  ...
#
#        coredata.publishercopyright coredata.article-number  \
# count                         2783                    1338
# unique                         850                    1262
# top         © 2023 by the authors.                      21
# freq                           263                       5
#
#        coredata.subtypeDescription coredata.prism:publicationName  \
# count                         2890                           2890
# unique                          11                           1514
# top                        Article             Scientific Reports
# freq                          2381                             93
#
#                     coredata.prism:doi coredata.dc:identifier  \
# count                             2816                   2890
# unique                            2816                   2890
# top     10.1016/j.ijbiomac.2023.126316  SCOPUS_ID:85170238281
# freq                                 1                      1
#
#        coredata.dc:publisher  \
# count                   2889
# unique                   305
# top             Elsevier Ltd
# freq                     277
#
#        item.bibrecord.head.citation-info.citation-language.@language  \
# count                                                2890
# unique                                                  1
# top                                               English
# freq                                                 2890
#
#        item.bibrecord.head.author-group.affiliation.country  \
# count                                                2890
# unique                                               1197
# top                                       Unknown,Unknown
# freq                                                  293
#
#        authkeywords.author-keyword
# count                         2890
# unique                        2413
# top                           null
# freq                           472
#
# [4 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2890 entries, 0 to 2889
# Data columns (total 25 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   coredata.srctype                                               2890 non-null   object
#  1   coredata.eid                                                   2890 non-null   object
#  2   coredata.dc:description                                        2798 non-null   object
#  3   coredata.pubmed-id                                             1050 non-null   object
#  4   coredata.prism:coverDate                                       2890 non-null   object
#  5   coredata.prism:aggregationType                                 2890 non-null   object
#  6   coredata.prism:url                                             2890 non-null   object
#  7   coredata.source-id                                             2890 non-null   object
#  8   coredata.pii                                                   757 non-null    object
#  9   coredata.citedby-count                                         2888 non-null   object
#  10  coredata.prism:volume                                          2502 non-null   object
#  11  coredata.subtype                                               2890 non-null   object
#  12  coredata.dc:title                                              2890 non-null   object
#  13  coredata.openaccess                                            2763 non-null   object
#  14  coredata.prism:issn                                            2761 non-null   object
#  15  coredata.publishercopyright                                    2783 non-null   object
#  16  coredata.article-number                                        1338 non-null   object
#  17  coredata.subtypeDescription                                    2890 non-null   object
#  18  coredata.prism:publicationName                                 2890 non-null   object
#  19  coredata.prism:doi                                             2816 non-null   object
#  20  coredata.dc:identifier                                         2890 non-null   object
#  21  coredata.dc:publisher                                          2889 non-null   object
#  22  item.bibrecord.head.citation-info.citation-language.@language  2890 non-null   object
#  23  item.bibrecord.head.author-group.affiliation.country           2890 non-null   object
#  24  authkeywords.author-keyword                                    2890 non-null   object
# dtypes: object(25)
# memory usage: 564.6+ KB

# %%
df.head(3)
# Out:
#   coredata.srctype        coredata.eid  \
# 0                b  2-s2.0-85128088236
# 1                j  2-s2.0-85122493175
# 2                j  2-s2.0-85127926459
#
#                              coredata.dc:description coredata.pubmed-id  \
# 0                                               <NA>               <NA>
# 1  We construct a Lagrangian for general nonlinea...           35061442
# 2                                               <NA>           35390937
#
#   coredata.prism:coverDate coredata.prism:aggregationType  \
# 0               2021-12-31                           Book
# 1               2021-12-31                        Journal
# 2               2021-12-30                        Journal
#
#                                   coredata.prism:url coredata.source-id  \
# 0  https://api.elsevier.com/content/abstract/scop...        21101084653
# 1  https://api.elsevier.com/content/abstract/scop...              29150
# 2  https://api.elsevier.com/content/abstract/scop...         4700151916
#
#   coredata.pii coredata.citedby-count  ...  \
# 0         <NA>                      0  ...
# 1         <NA>                      9  ...
# 2         <NA>                      0  ...
#
#                          coredata.publishercopyright coredata.article-number  \
# 0                                               <NA>                    <NA>
# 1  © 2021 authors. Published by the American Phys...                  271601
# 2                                               <NA>                    <NA>
#
#   coredata.subtypeDescription  \
# 0                Book Chapter
# 1                     Article
# 2                     Article
#
#                       coredata.prism:publicationName  \
# 0  Catheter Ablation of Cardiac Arrhythmias in Ch...
# 1                            Physical Review Letters
# 2                                            Zootaxa
#
#                coredata.prism:doi coredata.dc:identifier  \
# 0        10.1201/9781003082101-25  SCOPUS_ID:85128088236
# 1  10.1103/PhysRevLett.127.271601  SCOPUS_ID:85122493175
# 2       10.11646/zootaxa.5086.1.2  SCOPUS_ID:85127926459
#
#        coredata.dc:publisher  \
# 0                  CRC Press
# 1  American Physical Society
# 2              NLM (Medline)
#
#   item.bibrecord.head.citation-info.citation-language.@language  \
# 0                                            English
# 1                                            English
# 2                                            English
#
#   item.bibrecord.head.author-group.affiliation.country  \
# 0                               Spain,Spain,Thailand
# 1  United States,Russian Federation,Thailand,Belg...
# 2                       Thailand,New Zealand,Unknown
#
#   authkeywords.author-keyword
# 0                        null
# 1                        null
# 2                        null
#
# [3 rows x 25 columns]

# %% [markdown]
# # 2. Data Engineering

# %% [markdown]
# ### Data Cleansing

# %%
# Select the columns to keep and rename them
selected_columns = {
    'coredata.prism:coverDate': 'Year',
    'coredata.dc:title': 'Title',
    'coredata.prism:publicationName': 'PublicationName',
    'item.bibrecord.head.citation-info.citation-language.@language': 'Language',
    'coredata.citedby-count': 'CitedByCount',
    'item.bibrecord.head.author-group.affiliation.country': 'AffiliationCountry',
    'authkeywords.author-keyword': 'AuthorKeywords'
}
df_selected = df[list(selected_columns.keys())].rename(columns=selected_columns)

df_selected['Year'] = df_selected['Year'].str[:4]
df_selected = df_selected.dropna()
df_selected = df_selected[df_selected['AuthorKeywords'] != 'null']
df_selected = df_selected[~df_selected['AffiliationCountry'].str.contains('Unknown')]
df_selected['AffiliationCountry'] = df_selected['AffiliationCountry'].apply(lambda x: ','.join(set(x.split(','))))

df_selected['AffiliationCountry'] = df_selected['AffiliationCountry'].str.split(',')
df_selected['AuthorKeywords'] = df_selected['AuthorKeywords'].str.split(',')

# df_selected['Title'] = df_selected['Title'].astype(str)
# df_selected['PublicationName'] = df_selected['PublicationName'].astype(str)
# df_selected['Language'] = df_selected['Language'].astype(str)
# df_selected['AffiliationCountry'] = df_selected['AffiliationCountry'].astype(str)
df_selected['CitedByCount'] = df_selected['CitedByCount'].astype(int)

df_selected
# Out:
#       Year                                              Title  \
# 0     2023  Graphene oxide-alginate hydrogel-based indicat...
# 1     2023  Rare coordination behavior of triethanolamine ...
# 2     2023  Total ammonia nitrogen removal and microbial c...
# 3     2023  Effects of microaeration and sludge recirculat...
# 4     2023  Bioaccumulation of heavy metals in commerciall...
# ...    ...                                                ...
# 2884  2023  RSIAM risk profile for managing risk factors o...
# 2885  2023  Long-chain bio-olefins production via oxidativ...
# 2887  2023  Social justice, education and peacebuilding: c...
# 2888  2023  Effects of black soldier fly (Hermetia illucen...
# 2889  2023  Effects of remittances on household poverty an...
#
#                                         PublicationName Language  \
# 0     International Journal of Biological Macromolec...  English
# 1                        Journal of Molecular Structure  English
# 2                                           Aquaculture  English
# 3                      Science of the Total Environment  English
# 4                    Regional Studies in Marine Science  English
# ...                                                 ...      ...
# 2884   International Journal of Construction Management  English
# 2885                                    Catalysis Today  English
# 2887                                            Compare  English
# 2888                     Journal of Applied Aquaculture  English
# 2889                Journal of the Asia Pacific Economy  English
#
#       CitedByCount                                 AffiliationCountry  \
# 0                0                                         [Thailand]
# 1                0                                  [Thailand, India]
# 2                0                                         [Thailand]
# 3                0                                         [Thailand]
# 4                0  [United States, Thailand, India, Israel, Saudi...
# ...            ...                                                ...
# 2884             5                               [Thailand, Viet Nam]
# 2885             3                                         [Thailand]
# 2887             5                         [United Kingdom, Thailand]
# 2888             6                                         [Thailand]
# 2889             3                               [Cambodia, Thailand]
#
#                                          AuthorKeywords
# 0     [Alzheimer's disease, Hydrogel colorimetric se...
# 1     [Copper(II), Hirshfeld calculations, Molecular...
# 2     [Ammonia removal, Carrying capacity, Microbiom...
# 3     [Anaerobic baffled biofilm–MBR (AnBB-MBR), Mem...
# 4     [Contamination, Health risk assessment, Heavy ...
# ...                                                 ...
# 2884  [construction projects, international construc...
# 2885  [Long-chain olefins, Mesoporous KIT-6, Oleic a...
# 2887  [conflict, Education, peacebuilding, social ju...
# 2888  [Anabas testudineus, Black soldier fly, fish m...
# 2889  [Cambodia, consumption, expenditure, Impact, i...
#
# [2094 rows x 7 columns]

# %%
df_selected
# Out:
#       Year                                              Title  \
# 0     2023  Graphene oxide-alginate hydrogel-based indicat...
# 1     2023  Rare coordination behavior of triethanolamine ...
# 2     2023  Total ammonia nitrogen removal and microbial c...
# 3     2023  Effects of microaeration and sludge recirculat...
# 4     2023  Bioaccumulation of heavy metals in commerciall...
# ...    ...                                                ...
# 2884  2023  RSIAM risk profile for managing risk factors o...
# 2885  2023  Long-chain bio-olefins production via oxidativ...
# 2887  2023  Social justice, education and peacebuilding: c...
# 2888  2023  Effects of black soldier fly (Hermetia illucen...
# 2889  2023  Effects of remittances on household poverty an...
#
#                                         PublicationName Language  \
# 0     International Journal of Biological Macromolec...  English
# 1                        Journal of Molecular Structure  English
# 2                                           Aquaculture  English
# 3                      Science of the Total Environment  English
# 4                    Regional Studies in Marine Science  English
# ...                                                 ...      ...
# 2884   International Journal of Construction Management  English
# 2885                                    Catalysis Today  English
# 2887                                            Compare  English
# 2888                     Journal of Applied Aquaculture  English
# 2889                Journal of the Asia Pacific Economy  English
#
#       CitedByCount                                 AffiliationCountry  \
# 0                0                                         [Thailand]
# 1                0                                  [Thailand, India]
# 2                0                                         [Thailand]
# 3                0                                         [Thailand]
# 4                0  [United States, Thailand, India, Israel, Saudi...
# ...            ...                                                ...
# 2884             5                               [Thailand, Viet Nam]
# 2885             3                                         [Thailand]
# 2887             5                         [United Kingdom, Thailand]
# 2888             6                                         [Thailand]
# 2889             3                               [Cambodia, Thailand]
#
#                                          AuthorKeywords
# 0     [Alzheimer's disease, Hydrogel colorimetric se...
# 1     [Copper(II), Hirshfeld calculations, Molecular...
# 2     [Ammonia removal, Carrying capacity, Microbiom...
# 3     [Anaerobic baffled biofilm–MBR (AnBB-MBR), Mem...
# 4     [Contamination, Health risk assessment, Heavy ...
# ...                                                 ...
# 2884  [construction projects, international construc...
# 2885  [Long-chain olefins, Mesoporous KIT-6, Oleic a...
# 2887  [conflict, Education, peacebuilding, social ju...
# 2888  [Anabas testudineus, Black soldier fly, fish m...
# 2889  [Cambodia, consumption, expenditure, Impact, i...
#
# [2094 rows x 7 columns]

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2094 entries, 0 to 2889
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                2094 non-null   object
#  1   Title               2094 non-null   object
#  2   PublicationName     2094 non-null   object
#  3   Language            2094 non-null   object
#  4   CitedByCount        2094 non-null   int32
#  5   AffiliationCountry  2094 non-null   object
#  6   AuthorKeywords      2094 non-null   object
# dtypes: int32(1), object(6)
# memory usage: 122.7+ KB
